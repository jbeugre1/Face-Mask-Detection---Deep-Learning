# %%
import os
import random as rand
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from numpy import asarray
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Embedding, BatchNormalization, Conv2D, MaxPool2D, Activation, MaxPooling2D, Dropout,AveragePooling2D, Flatten
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
# Out:
# 2022-12-08 12:03:14.854624: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = tf.keras.models.load_model('mask_detector_v3.h5')
# Out:
# 2022-12-08 12:03:18.497598: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory("/Users/cedricbeugre/Desktop/Deep-learning-Project-1/Dataset/Train",batch_size=32,image_size=(256, 256),shuffle=True)
test_dataset = tf.keras.utils.image_dataset_from_directory("/Users/cedricbeugre/Desktop/Deep-learning-Project-1/Dataset/Test",batch_size=32,image_size=(256, 256),shuffle=True)

class_names = train_dataset.class_names
print(class_names)
# Out:
# Found 12396 files belonging to 3 classes.
# Found 3373 files belonging to 3 classes.
# ['Incorrectly', 'Withmask', 'Withoutmask']

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
modelFile = "res10_300x300_ssd_iter_140000.caffemodel"
configFile = "deploy.prototxt"

while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    net = cv2.dnn.readNetFromCaffe(configFile, modelFile)
    h, w = frame.shape[:2]
    
    blob = cv2.dnn.blobFromImage(cv2.resize(frame, (300, 300)), 1.0, (300, 300), (104.0, 117.0, 123.0))
    net.setInput(blob)
    faces = net.forward()

    for i in range(0, faces.shape[2]):
        confidence = faces[0, 0, i, 2]
        if confidence > 0.5:
            box = faces[0, 0, i, 3:7] * np.array([w, h, w, h])
            
            (x, y, x1, y1) = box.astype("int")
            
            
            face = frame[y:y1, x:x1]
            face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
            face = cv2.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)
            face = np.expand_dims(face, axis=0)
            preds = model.predict(face)

            if preds[0].argmax() == 0:
                cv2.rectangle(frame, (x, y-40), (x1, y), (0, 255, 255), -1)
                cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 255), 3)
                cv2.putText(frame, 'Incorrectly Masked', (x+10, y-9), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
            elif preds[0].argmax() == 1:
                cv2.rectangle(frame, (x, y-40), (x1, y), (0, 255, 0), -1)
                cv2.rectangle(frame, (x, y), (x1, y1), (0, 255, 0), 3)
                cv2.putText(frame, 'Correctly Masked', (x+10, y-9), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
            elif preds[0].argmax() == 2:
                cv2.rectangle(frame, (x, y-40), (x1, y), (0, 0, 255), -1)
                cv2.rectangle(frame, (x, y), (x1, y1), (0, 0, 255), 3)
                cv2.putText(frame, 'No Mask', (x+10, y-9), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
            print(class_names[preds[0].argmax()])
            
            
 
    cv2.imshow('Webcam',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 1/1 [==============================] - 1s 518ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 38ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 29ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 33ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 33ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 34ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 32ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Incorrectly
# 1/1 [==============================] - 0s 31ms/step
# Incorrectly
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 32ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 49ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 38ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 36ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 36ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# ...
# Withoutmask
# 1/1 [==============================] - 0s 127ms/step
# Withoutmask
# 1/1 [==============================] - 0s 108ms/step
# Withoutmask
# 1/1 [==============================] - 0s 136ms/step
# Withoutmask
# 1/1 [==============================] - 0s 49ms/step
# Withoutmask
# 1/1 [==============================] - 0s 185ms/step
# Withoutmask
# 1/1 [==============================] - 0s 58ms/step
# Withoutmask
# 1/1 [==============================] - 0s 105ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 186ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 92ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 48ms/step
# Withoutmask
# 1/1 [==============================] - 0s 52ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 48ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 53ms/step
# Withoutmask
# 1/1 [==============================] - 0s 58ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 42ms/step
# Withoutmask
# 1/1 [==============================] - 0s 47ms/step
# Withoutmask
# 1/1 [==============================] - 0s 45ms/step
# Withoutmask
# 1/1 [==============================] - 0s 48ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 54ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 38ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 69ms/step
# Withoutmask
# 1/1 [==============================] - 0s 44ms/step
# Withoutmask
# 1/1 [==============================] - 0s 55ms/step
# Withoutmask
# 1/1 [==============================] - 0s 58ms/step
# Withoutmask
# 1/1 [==============================] - 0s 185ms/step
# Withoutmask
# 1/1 [==============================] - 0s 151ms/step
# Withoutmask
# 1/1 [==============================] - 0s 233ms/step
# Withoutmask
# 1/1 [==============================] - 0s 83ms/step
# Withoutmask
# 1/1 [==============================] - 0s 226ms/step
# Withoutmask
# 1/1 [==============================] - 0s 160ms/step
# Withoutmask
# 1/1 [==============================] - 0s 72ms/step
# Withoutmask
# 1/1 [==============================] - 0s 65ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 47ms/step
# Withoutmask
# 1/1 [==============================] - 0s 51ms/step
# Withoutmask
# 1/1 [==============================] - 0s 42ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 52ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 68ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 49ms/step
# Withoutmask
# 1/1 [==============================] - 0s 99ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 75ms/step
# Withoutmask
# 1/1 [==============================] - 0s 128ms/step
# Withoutmask
# 1/1 [==============================] - 0s 75ms/step
# Withoutmask
# 1/1 [==============================] - 0s 71ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 38ms/step
# Withoutmask
# 1/1 [==============================] - 0s 38ms/step
# Withoutmask
# 1/1 [==============================] - 0s 47ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 42ms/step
# Withoutmask
# 1/1 [==============================] - 0s 50ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 62ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 30ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 45ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 111ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 82ms/step
# Withoutmask
# 1/1 [==============================] - 0s 73ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 47ms/step
# Withoutmask
# 1/1 [==============================] - 0s 42ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 52ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 50ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 32ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 40ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 53ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 39ms/step
# Withoutmask
# 1/1 [==============================] - 0s 44ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 138ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 45ms/step
# Withoutmask
# 1/1 [==============================] - 0s 37ms/step
# Withoutmask
# 1/1 [==============================] - 0s 43ms/step
# Withoutmask
# 1/1 [==============================] - 0s 48ms/step
# Withoutmask
# 1/1 [==============================] - 0s 46ms/step
# Withoutmask
# 1/1 [==============================] - 0s 41ms/step
# Withoutmask
# 1/1 [==============================] - 0s 34ms/step
# Withoutmask
# 1/1 [==============================] - 0s 33ms/step
# Withoutmask
# 1/1 [==============================] - 0s 58ms/step
# Withoutmask
# 1/1 [==============================] - 0s 31ms/step
# Withoutmask
# 1/1 [==============================] - 0s 35ms/step
# Withoutmask
# 1/1 [==============================] - 0s 56ms/step
# Withoutmask
# 1/1 [==============================] - 0s 98ms/step
# Withoutmask
# 1/1 [==============================] - 0s 122ms/step
# Withoutmask
# 1/1 [==============================] - 0s 119ms/step
# Withoutmask
# 1/1 [==============================] - 0s 156ms/step
# Withoutmask
# 1/1 [==============================] - 0s 86ms/step
# Withoutmask
# 1/1 [==============================] - 0s 52ms/step
# Withoutmask
# 1/1 [==============================] - 0s 75ms/step
# Withoutmask
# 1/1 [==============================] - 0s 66ms/step
# Withoutmask
# 1/1 [==============================] - 0s 184ms/step
# Withoutmask
# 1/1 [==============================] - 0s 251ms/step
# Withoutmask
# 1/1 [==============================] - 0s 118ms/step
# Withoutmask
# 1/1 [==============================] - 0s 101ms/step
# Withoutmask
# 1/1 [==============================] - 0s 115ms/step
# Withoutmask
# 1/1 [==============================] - 0s 84ms/step
# Withoutmask
# 1/1 [==============================] - 0s 98ms/step
# Withoutmask
# 1/1 [==============================] - 0s 138ms/step
# Withoutmask
# 1/1 [==============================] - 0s 315ms/step
# Withoutmask
# 1/1 [==============================] - 0s 82ms/step
# Withoutmask
# 1/1 [==============================] - 0s 62ms/step
# Withoutmask
# 1/1 [==============================] - 0s 87ms/step
# Withoutmask
# 1/1 [==============================] - 0s 191ms/step
# Withoutmask
# 1/1 [==============================] - 0s 207ms/step
# Withoutmask
# 1/1 [==============================] - 0s 90ms/step
# Withoutmask
# 1/1 [==============================] - 1s 522ms/step
# Withoutmask
# 1/1 [==============================] - 0s 174ms/step
# Withoutmask
# 1/1 [==============================] - 0s 115ms/step
# Withoutmask
# 1/1 [==============================] - 0s 130ms/step
# Withoutmask
# 1/1 [==============================] - 0s 154ms/step
# Withoutmask
# 1/1 [==============================] - 0s 114ms/step
# Withoutmask
# 1/1 [==============================] - 0s 165ms/step
# Withoutmask
# 1/1 [==============================] - 0s 83ms/step
# Withoutmask
# 1/1 [==============================] - 0s 103ms/step
# Withoutmask
# 1/1 [==============================] - 0s 185ms/step
# Withoutmask
# 1/1 [==============================] - 0s 94ms/step
# Withoutmask
# 1/1 [==============================] - 0s 118ms/step
# Withoutmask
# 1/1 [==============================] - 0s 173ms/step
# Withoutmask
# 1/1 [==============================] - 0s 139ms/step
# Withoutmask
# 1/1 [==============================] - 0s 115ms/step
# Withoutmask
# 1/1 [==============================] - 0s 148ms/step
# Withoutmask
# 1/1 [==============================] - 0s 132ms/step
# Withoutmask
# 1/1 [==============================] - 0s 151ms/step
# Withoutmask
# 1/1 [==============================] - 0s 133ms/step
# Withoutmask
# 1/1 [==============================] - 0s 146ms/step
# Withoutmask
# 1/1 [==============================] - 0s 76ms/step
# Withoutmask
# 1/1 [==============================] - 0s 119ms/step
# Withoutmask
# 1/1 [==============================] - 0s 97ms/step
# Withoutmask
# 1/1 [==============================] - 0s 87ms/step
# Withoutmask
# 1/1 [==============================] - 0s 153ms/step
# Withoutmask
# 1/1 [==============================] - 0s 250ms/step
# Withoutmask
# 1/1 [==============================] - 0s 115ms/step
# Withoutmask
# 1/1 [==============================] - 0s 142ms/step
# Withoutmask
# 1/1 [==============================] - 0s 142ms/step
# Withoutmask
# 1/1 [==============================] - 0s 136ms/step
# Withoutmask
# 1/1 [==============================] - 0s 76ms/step
# Withoutmask
# 1/1 [==============================] - 0s 93ms/step
# Withoutmask
# 1/1 [==============================] - 0s 110ms/step
# Withoutmask
# 1/1 [==============================] - 0s 206ms/step
# Withoutmask
# 1/1 [==============================] - 0s 110ms/step
# Withoutmask
# 1/1 [==============================] - 0s 153ms/step
# Withoutmask
# 1/1 [==============================] - 0s 151ms/step
# Withoutmask
# 1/1 [==============================] - 0s 106ms/step
# Withoutmask
# 1/1 [==============================] - 0s 151ms/step
# Withoutmask
# 1/1 [==============================] - 0s 98ms/step
# Withoutmask
# 1/1 [==============================] - 0s 363ms/step
# Withoutmask
# 1/1 [==============================] - 0s 96ms/step
# Withoutmask
# 1/1 [==============================] - 0s 144ms/step
# Withoutmask
# 1/1 [==============================] - 0s 184ms/step
# Withoutmask
# 1/1 [==============================] - 0s 152ms/step
# Withoutmask
# 1/1 [==============================] - 0s 123ms/step
# Withoutmask
# 1/1 [==============================] - 0s 59ms/step
# Withoutmask
# 1/1 [==============================] - 0s 91ms/step
# Withoutmask
# 1/1 [==============================] - 0s 159ms/step
# Withoutmask
# 1/1 [==============================] - 0s 111ms/step
# Withoutmask
# 1/1 [==============================] - 0s 111ms/step
# Withoutmask
# 1/1 [==============================] - 0s 81ms/step
# Withoutmask
# 1/1 [==============================] - 0s 72ms/step
# Withoutmask
# 1/1 [==============================] - 0s 68ms/step
# Withoutmask
# 1/1 [==============================] - 0s 64ms/step
# Withoutmask
# 1/1 [==============================] - 0s 134ms/step
# Withoutmask
# 1/1 [==============================] - 0s 97ms/step
# Withoutmask
# 1/1 [==============================] - 0s 130ms/step
# Withoutmask
# 1/1 [==============================] - 0s 123ms/step
# Withoutmask
# 1/1 [==============================] - 0s 93ms/step
# Withoutmask
# 1/1 [==============================] - 0s 128ms/step
# Withoutmask
# 1/1 [==============================] - 0s 92ms/step
# Withoutmask
# 1/1 [==============================] - 0s 139ms/step
# Withoutmask
# 1/1 [==============================] - 0s 136ms/step
# Withoutmask
# 1/1 [==============================] - 0s 71ms/step
# Withoutmask
# 1/1 [==============================] - 0s 129ms/step
# Withoutmask
# 1/1 [==============================] - 0s 79ms/step
# Withoutmask
# 1/1 [==============================] - 0s 109ms/step
# Withoutmask
# 1/1 [==============================] - 0s 105ms/step
# Withoutmask
